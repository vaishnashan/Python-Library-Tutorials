# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import pandas as pd
df=pd.DataFrame({"name":['a','b','c'],"mark":[1,2,1]})
df
# Out:
#   name  mark
# 0    a     1
# 1    b     2
# 2    c     1

# %%
sns.lineplot(x="name",y="mark",data=df)
plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd
df=pd.DataFrame({"name":['a','b','c'],"mark":[1,2,1],"hi":[4,92,4]})
df
plt.show()

# %%
df
# Out:
#   name  mark  hi
# 0    a     1   4
# 1    b     2  92
# 2    c     1   4

# %%
import seaborn as sns
sns.lineplot(x="name",y="mark",data=df , hue="hi")
plt.show()
